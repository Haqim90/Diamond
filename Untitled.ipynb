# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# This classic dataset contains the prices and other attributes of almost 54,000 diamonds.
# Find wich attributes  is more correlated to the diamond price

# %% [markdown]
# price: price in US dollars (\$326--\$18,823)
#
# carat: weight of the diamond (0.2--5.01)
#
# cut: quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# color; diamond colour, from J (worst) to D (best)
#
# clarity: a measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# x: length in mm (0--10.74)
#
# y: width in mm (0--58.9)
#
# z: depth in mm (0--31.8)
#
# depth total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# table width of top of diamond relative to widest point (43--95)

# %%
df=pd.read_csv('diamonds.csv')
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.nunique()
# Out:
# Unnamed: 0    53940
# carat           273
# cut               5
# color             7
# clarity           8
# depth           184
# table           127
# price         11602
# x               554
# y               552
# z               375
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool

# %%
df.isnull()
# Out:
#        Unnamed: 0  carat    cut  color  clarity  depth  table  price      x  \
# 0           False  False  False  False    False  False  False  False  False
# 1           False  False  False  False    False  False  False  False  False
# 2           False  False  False  False    False  False  False  False  False
# 3           False  False  False  False    False  False  False  False  False
# 4           False  False  False  False    False  False  False  False  False
# ...           ...    ...    ...    ...      ...    ...    ...    ...    ...
# 53935       False  False  False  False    False  False  False  False  False
# 53936       False  False  False  False    False  False  False  False  False
# 53937       False  False  False  False    False  False  False  False  False
# 53938       False  False  False  False    False  False  False  False  False
# 53939       False  False  False  False    False  False  False  False  False
#
#            y      z
# 0      False  False
# ...

# %%
df.isna()
# Out:
#        Unnamed: 0  carat    cut  color  clarity  depth  table  price      x  \
# 0           False  False  False  False    False  False  False  False  False
# 1           False  False  False  False    False  False  False  False  False
# 2           False  False  False  False    False  False  False  False  False
# 3           False  False  False  False    False  False  False  False  False
# 4           False  False  False  False    False  False  False  False  False
# ...           ...    ...    ...    ...      ...    ...    ...    ...    ...
# 53935       False  False  False  False    False  False  False  False  False
# 53936       False  False  False  False    False  False  False  False  False
# 53937       False  False  False  False    False  False  False  False  False
# 53938       False  False  False  False    False  False  False  False  False
# 53939       False  False  False  False    False  False  False  False  False
#
#            y      z
# 0      False  False
# ...

# %%
#delete duplicates
df.drop_duplicates()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.shape
# Out:
# (53940, 11)

# %%
#delete missing values 
df.dropna()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0.23, 'Ideal', ..., 3.95, 3.98, 2.43],
#        [2, 0.21, 'Premium', ..., 3.89, 3.84, 2.31],
#        [3, 0.23, 'Good', ..., 4.05, 4.07, 2.31],
#        ...,
#        [53938, 0.7, 'Very Good', ..., 5.66, 5.68, 3.56],
#        [53939, 0.86, 'Premium', ..., 6.15, 6.12, 3.74],
#        [53940, 0.75, 'Ideal', ..., 5.83, 5.87, 3.64]], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=53940, step=1)

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
cut=df.groupby([ 'carat', 'cut'])[['price']].mean().sort_values('price', ascending=False)
cut
# Out:
#                     price
# carat cut
# 2.80  Good       18788.00
# 2.36  Premium    18745.00
# 1.94  Premium    18735.00
# 3.51  Premium    18701.00
# 2.67  Good       18686.00
# ...                   ...
# 0.23  Fair         369.00
# 0.20  Very Good    367.00
#       Ideal        367.00
#       Premium      364.25
# 0.22  Fair         337.00
#
# [1098 rows x 1 columns]

# %%
fig, ax=plt.subplots(figsize=(6.4, 4))
sns.set_style('darkgrid')
sns.barplot(x='cut', y='price', data=df)

ax.set_title('Average Carat Weight by Cut Quality', fontsize=16)
ax.set_xlabel('Cut Quality')
ax.set_ylabel('Carat Weight')
# Out:
# Text(0, 0.5, 'Carat Weight')

# %%
sns.boxplot(x='cut', y='price', data=df)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.violinplot(x='cut', y='price', data=df)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.histplot(x='price', data=df, bins=20, kde=True, hue='cut', alpha=.3, stat='percent')
# Out:
# <Axes: xlabel='price', ylabel='Percent'>

# %%
sns.histplot(y='price', data=df, hue='cut', )
# Out:
# <Axes: xlabel='Count', ylabel='price'>

# %%
sns.histplot(x='carat', data=df, hue='cut',kde=True, bins=10, alpha=.3, stat='percent')
# Out:
# <Axes: xlabel='carat', ylabel='Percent'>

# %%
sns.boxplot(y='carat', x='cut', data=df)
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
#fig, ax=plt.subplots(figsize(8,8))

sns.boxplot(x='color', y='price', data=df)
#ax.set_title('Diammonds price by color', figsize=16)
#ax.set_xlabel('color')
#ax.set_label('price')
# Out:
# <Axes: xlabel='color', ylabel='price'>

# %%
#fig, ax=plt.subplot()
sns.boxplot(x='clarity', y='price', data=df);
#ax.set_title('diamonds price by clarity')
#ax.set_xlabel('clarity')
#ax.set_ylabel('price')
#plt.xlim([,])
#plt.ylim([,])

# %%
fig, ax=plt.subplots(figsize=(8,8))
sns.scatterplot(x='carat', y='price', hue='cut', data=df)

ax.set_title('Correlation between diamonds weight and price')
ax.set_xlabel('Diamonds weight')
ax.set_ylabel('Price')
#plt.xlim([0,5])
#plt.ylim([0,17000])
# Out:
# Text(0, 0.5, 'Price')

# %%
sns.relplot(x='carat', y='price', data=df, kind='line',  hue='cut', col='cut');

# %%
sns.regplot(x='carat', y='price', data=df);

# %%
sns.lmplot(x='carat', y='price', hue='cut',col='cut', row='color', data=df);

# %%
sns.pairplot(df.loc[:,['price', 'x','y','z','depth', 'carat']]);

# %%
diamond=df[['carat', 'depth', 'table','price', 'x', 'y', 'z']]
#corr=diamond.corr()

# %%
diamond
# Out:
#        carat  depth  table  price     x     y     z
# 0       0.23   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31   63.3   58.0    335  4.34  4.35  2.75
# ...      ...    ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 7 columns]

# %%
corr=diamond.corr()

# %%
sns.heatmap(corr, annot=True);

# %% [markdown]
# From the data we can see that carat  is more correlated with the price.
